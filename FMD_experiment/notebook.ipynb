# %% [markdown]
# # FMD experiment

# %% [markdown]
# ## Part 1

# %% [markdown]
# We are using Random Forest to classify images appearing in the FMD database using TDA methods.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from itertools import combinations

data = pd.read_csv('new.csv')

nes = list(range(1,256))
betti = list(range(256,511))
sil = list(range(511, 766))
sil5 = list(range(766, 1021))
sil10 = list(range(1021, 1276))
#number of estimators
num = 100

# %% [markdown]
# We apply the Random Forest algorithm in each possible case. Different functions are combined via concatenation.

# %%
fun_list = [nes, betti, sil, sil5, sil10, nes + betti, sil + nes, sil5 + nes, sil10 + nes, betti +  sil,
            betti +  sil5, betti +  sil10, sil + nes + betti, sil5 + nes + betti, sil10 + nes + betti]
aux = []
for fun in fun_list:
    X = data.iloc[:, fun].values
    y = data.iloc[:, 0].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    #Create a Gaussian Classifier
    clf=RandomForestClassifier(n_estimators=num, random_state = 0)
    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    # Model Accuracy, how often is the classifier correct?
    aux.append(metrics.accuracy_score(y_test, y_pred))

# %%
names = ["nes", "betti", "sil", "sil5", "sil10", "nes + betti", "sil + nes", "sil5 + nes", "sil10 + nes",
         "betti +  sil",  "betti +  sil5", "betti +  sil10", "sil + nes + betti", "sil5 + nes + betti",
         "sil10 + nes + betti"]
for i in range(len(fun_list)):
    print("Accuracy", names[i], ":", aux[i])
# Out:
# Accuracy nes : 0.24
# Accuracy betti : 0.285
# Accuracy sil : 0.185
# Accuracy sil5 : 0.14
# Accuracy sil10 : 0.125
# Accuracy nes + betti : 0.29
# Accuracy sil + nes : 0.25
# Accuracy sil5 + nes : 0.245
# Accuracy sil10 + nes : 0.24
# Accuracy betti +  sil : 0.285
# Accuracy betti +  sil5 : 0.26
# Accuracy betti +  sil10 : 0.27
# Accuracy sil + nes + betti : 0.265
# Accuracy sil5 + nes + betti : 0.27
# Accuracy sil10 + nes + betti : 0.27

# %% [markdown]
# ## Part 2

# %% [markdown]
# In this case, we will try to classify categories pairwise. We will see how different TDA methods may be better depending on the data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from itertools import combinations

data = pd.read_csv('new.csv')
data_persim = pd.read_csv('db_persim.csv')
data_persim = data_persim[map(str,range(401))]

nes = list(range(1,256))
betti = list(range(256,511))
sil = list(range(511, 766))

#number of estimators
num = 100
#create the pairs
com = combinations(range(10), 2)

# %%
results = pd.DataFrame()

for pair in com:
    auxrow = []
    db = data.loc[[x[0] | x[1] for x in zip(data['labels'] == pair[0],  data['labels'] == pair[1])]]
    y = db.iloc[:, 0].values
    
    X = db.iloc[:, betti].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    clf=RandomForestClassifier(n_estimators=num, random_state = 0)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    auxrow.append(metrics.accuracy_score(y_test, y_pred))
    
    X = db.iloc[:, sil].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    clf=RandomForestClassifier(n_estimators=num, random_state = 0)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    auxrow.append(metrics.accuracy_score(y_test, y_pred))
    
    X = db.iloc[:, nes].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    clf=RandomForestClassifier(n_estimators=num, random_state = 0)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    auxrow.append(metrics.accuracy_score(y_test, y_pred))

    
    db = data_persim.loc[[x[0] | x[1] for x in zip(data_persim['0'] == pair[0],  data_persim['0'] == pair[1])]]
    y = db.iloc[:, 0].values
    X = db.iloc[:, 1:401].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    clf=RandomForestClassifier(n_estimators=num, random_state = 0)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    auxrow.append(metrics.accuracy_score(y_test, y_pred))
    
    results = pd.DataFrame([auxrow]).append(results, ignore_index=True)

# %%
#Create a function to bold the maximum value
def highlight_max(s):
    is_max = s == s.max()
    return ['font-weight: bold' if v else '' for v in is_max]

# %%
names = ['betti', 'sil', 'nes', 'persim']
results.columns = names
results.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row0_col1 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row1_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row2_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row3_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row4_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row5_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row6_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row7_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row8_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row9_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row9_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row10_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row11_col1 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row12_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row12_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row13_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row14_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row15_col1 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row16_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row16_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row17_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row18_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row19_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row20_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row21_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row22_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row22_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row23_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row24_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row25_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row26_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row27_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row27_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row28_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row29_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row29_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row30_col1 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row30_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row31_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row32_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row33_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row34_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row35_col2 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row36_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row37_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row38_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row39_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row40_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row41_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row42_col0 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row43_col3 {
#             font-weight:  bold;
#         }    #T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row44_col0 {
#             font-weight:  bold;
#         }</style><table id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >betti</th>        <th class="col_heading level0 col1" >sil</th>        <th class="col_heading level0 col2" >nes</th>        <th class="col_heading level0 col3" >persim</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row0_col0" class="data row0 col0" >0.6</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row0_col1" class="data row0 col1" >0.625</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row0_col2" class="data row0 col2" >0.5</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row0_col3" class="data row0 col3" >0.55</td>
#             </tr>
#             <tr>
#                         <th id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row1_col0" class="data row1 col0" >0.675</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row1_col1" class="data row1 col1" >0.525</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row1_col2" class="data row1 col2" >0.6</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row1_col3" class="data row1 col3" >0.725</td>
#             </tr>
#             <tr>
#                         <th id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row2_col0" class="data row2 col0" >0.7</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row2_col1" class="data row2 col1" >0.55</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row2_col2" class="data row2 col2" >0.7</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row2_col3" class="data row2 col3" >0.8</td>
#             </tr>
#             <tr>
#                         <th id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row3_col0" class="data row3 col0" >0.6</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row3_col1" class="data row3 col1" >0.45</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row3_col2" class="data row3 col2" >0.5</td>
#                         <td id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9row3_col3" class="data row3 col3" >0.675</td>
#             </tr>
#             <tr>
#                         <th id="T_9148b91c_774a_11ea_85c1_d0bf9c6040a9level0_row4" class="row_h
